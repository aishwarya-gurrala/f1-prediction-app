# %%
import os

# Your capstone folder
BASE_DIR = r"C:\Users\aishw\OneDrive\Desktop\F1predictoncap"

# New folder for storing evaluation outputs
SAVE_DIR = os.path.join(BASE_DIR, "Model_Evaluation")

# Create folder if it does not exist
os.makedirs(SAVE_DIR, exist_ok=True)

SAVE_DIR
# Out:
# 'C:\\Users\\aishw\\OneDrive\\Desktop\\F1predictoncap\\Model_Evaluation'

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc
import pandas as pd

# --------------------------------------------------------
# ROC CURVE FOR ALL MODELS
# --------------------------------------------------------
plt.figure(figsize=(6,4))

# Logistic Regression
fpr_log, tpr_log, _ = roc_curve(y_test, log_reg.predict_proba(X_test)[:,1])
auc_log = auc(fpr_log, tpr_log)
plt.plot(fpr_log, tpr_log, label=f"Logistic Regression (AUC={auc_log:.3f})")

# Random Forest
fpr_rf, tpr_rf, _ = roc_curve(y_test, rf.predict_proba(X_test)[:,1])
auc_rf = auc(fpr_rf, tpr_rf)
plt.plot(fpr_rf, tpr_rf, label=f"Random Forest (AUC={auc_rf:.3f})")

# XGBoost
fpr_xgb, tpr_xgb, _ = roc_curve(y_test, xgb.predict_proba(X_test)[:,1])
auc_xgb = auc(fpr_xgb, tpr_xgb)
plt.plot(fpr_xgb, tpr_xgb, label=f"XGBoost (AUC={auc_xgb:.3f})", linewidth=3)

# Diagonal baseline
plt.plot([0,1], [0,1], 'k--', alpha=0.5)

plt.title("ROC Curve — All Models")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend()

# Save inside new folder
plt.savefig(os.path.join(SAVE_DIR, "roc_all_models.png"), dpi=300, bbox_inches="tight")
plt.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 11
#       8 plt.figure(figsize=(6,4))
#      10 # Logistic Regression
# ---> 11 fpr_log, tpr_log, _ = roc_curve(y_test, log_reg.predict_proba(X_test)[:,1])
#      12 auc_log = auc(fpr_log, tpr_log)
#      13 plt.plot(fpr_log, tpr_log, label=f"Logistic Regression (AUC={auc_log:.3f})")
#
# NameError: name 'y_test' is not defined

# %%
import os

BASE_DIR = r"C:\Users\aishw\OneDrive\Desktop\F1predictoncap"
SAVE_DIR = os.path.join(BASE_DIR, "Model_Evaluation")

os.makedirs(SAVE_DIR, exist_ok=True)

print("Folder created at:", SAVE_DIR)
# Out:
# Folder created at: C:\Users\aishw\OneDrive\Desktop\F1predictoncap\Model_Evaluation

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

# Compute ROC curves & AUC for each model
fpr_log, tpr_log, _ = roc_curve(y_test, log_reg.predict_proba(X_test)[:, 1])
auc_log = auc(fpr_log, tpr_log)

fpr_rf, tpr_rf, _ = roc_curve(y_test, rf.predict_proba(X_test)[:, 1])
auc_rf = auc(fpr_rf, tpr_rf)

fpr_xgb, tpr_xgb, _ = roc_curve(y_test, xgb.predict_proba(X_test)[:, 1])
auc_xgb = auc(fpr_xgb, tpr_xgb)

print("AUC values:")
print("  Logistic Regression:", round(auc_log, 3))
print("  Random Forest      :", round(auc_rf, 3))
print("  XGBoost            :", round(auc_xgb, 3))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 5
#       2 from sklearn.metrics import roc_curve, auc
#       4 # Compute ROC curves & AUC for each model
# ----> 5 fpr_log, tpr_log, _ = roc_curve(y_test, log_reg.predict_proba(X_test)[:, 1])
#       6 auc_log = auc(fpr_log, tpr_log)
#       8 fpr_rf, tpr_rf, _ = roc_curve(y_test, rf.predict_proba(X_test)[:, 1])
#
# NameError: name 'y_test' is not defined
