# %%
# Merge race info into results
df = results.merge(races[['raceId', 'year', 'round', 'circuitId', 'name']], on='raceId', how='left')

# Merge driver and constructor info
df = df.merge(drivers[['driverId', 'forename', 'surname', 'nationality']], on='driverId', how='left')
df = df.merge(constructors[['constructorId', 'name']], on='constructorId', how='left', suffixes=('', '_constructor'))

# %%
import pandas as pd

# Load the Excel sheets (change .xlsx to .csv if needed)
races = pd.read_excel('races.xlsx')
results = pd.read_excel('results.xlsx')
drivers = pd.read_excel('drivers.xlsx')
constructors = pd.read_excel('constructors.xlsx')
qualifying = pd.read_excel('qualifying.xlsx')
driver_standings = pd.read_excel('driver_standings.xlsx')
constructor_standings = pd.read_excel('constructor_standings.xlsx')
